# %%
# Load numpy for math/array operations
# and matplotlib for plotting
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# Set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['figure.dpi'] = 150

# %%
import pandas as pd

# %% [markdown]
# # Plotting Series

# %%
# Basic Series Plot 
p = pd.Series(np.random.randn(1000))

# %%
# Histogram & KDE

# %%
# Plotting with Date indices
p = pd.Series(np.random.randn(1000), index=pd.date_range('01/01/1900',periods=1000))

# %% [markdown]
# # Plotting DataFrames

# %%
df = pd.DataFrame(np.random.randn(1000,3), columns=['one', 'two', 'three']).cumsum()
df.head()
# Out:
#         one       two     three
# 0  0.013496  0.471833  0.812634
# 1  0.218282 -1.173527  1.589273
# 2  1.438572 -0.078629  2.578976
# 3  0.645096 -1.649392  2.907407
# 4  1.100726 -3.591090  1.949541

# %%
# Basic DataFramePlot
df.plot()

# %%
# Plotting data choice

# %%
# Bar plots
df[0:4]
# Out:
#         one       two     three
# 0  0.013496  0.471833  0.812634
# 1  0.218282 -1.173527  1.589273
# 2  1.438572 -0.078629  2.578976
# 3  0.645096 -1.649392  2.907407

# %%
# Tables

# %%
# Read from file
crop_prod = pd.read_csv('OECD-THND_TONNES.txt',delimiter='\t')

# %%
years = crop_prod[crop_prod['Crop']=='SOYBEAN']['Year']
rice = crop_prod[crop_prod['Crop']=='RICE']['Value']
wheat = crop_prod[crop_prod['Crop']=='WHEAT']['Value']
maize = crop_prod[crop_prod['Crop']=='MAIZE']['Value']
soybean = crop_prod[crop_prod['Crop']=='SOYBEAN']['Value']

# %%
# Plot the data series
plt.plot(years, rice, label='Rice')
plt.plot(years, wheat, label='Wheat')
plt.plot(years, maize, label='Maize')
plt.plot(years, soybean, label='Soybean')

# %%
# Plot the data series
plt.plot(years, rice, label='Rice')
plt.plot(years, wheat, label='Wheat')
plt.plot(years, maize, label='Maize')
plt.plot(years, soybean, label='Soybean')
# Label the x- and y-axes
plt.xlabel('Year',size=12,fontweight='semibold')
plt.ylabel('Thousand tonnes',size=12,fontweight='semibold')

# Add grid
plt.grid(linestyle='--',color='#888888',alpha=0.4)

# Add the title and legend
plt.title('Total OECD crop production in 1995-2016', size=14, fontweight='semibold')
plt.legend()

# Show the figure
plt.show()
